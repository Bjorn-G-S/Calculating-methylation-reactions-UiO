# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
# %gui asyncio

from MTMTH_excel import *

obj = excel_MTMTH_Calc()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
#         Here are the fucntions that are included in the class. This is meant to be used together with Jupyter LAB:
#
#         obj.Quantify()                                    Quantify and integrate the results from GC
#
#         obj.plot(form="total over time")                 Plot total Yield produced over time
#         obj.plot(form="")                                Plot  Yield produced vs time
# Dropdown(description='Eksperiment:', layout=Layout(width='30%'), options=(('220113_Area%_HMOR6_150C.xlsx', 'C:…

# %%
obj.Quantify()
# Out:
# POPYLENE EXPERIMENT
#                             0      1       2       3    4
# Species                    C4     C5      C6      C7   C8
# Yield (micromol/gram)  67.529  54.88  530.63  43.935  0.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
obj.plot(form="total over time")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
obj.plot(form="For integral")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
